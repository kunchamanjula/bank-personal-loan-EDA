# %% [markdown]
# **HELLO all :) thankyou for visting my notebook .
# * please give an upvote if it is useful to you and also give me your valuable feedback on this notes
# * thankyou all:)

# %% [markdown]
# # EMPLOYEE ATTRITION EDA AND VISUVALIZATON

# %% [markdown]
# # import libraries

# %%
import numpy as np  #for numeric operations
import pandas as pd #to analyse,clean,filter,manipulate ,explore datasets
import matplotlib.pyplot as plt #Data visuvalization and analysis
# %matplotlib inline
import seaborn as sns #for advance visuvalizations with matplotlib
from IPython.display import Image  #importing libary to display the image
import os #import operating system to direct the folders
import datetime # datetime is useful to date_time series analysis

# %% [markdown]
# # ignore warnings:

# %%
import warnings
warnings.simplefilter(action="ignore",category=FutureWarning)

# %% [markdown]
# # Employee Attrition
#
# * Employee attrition, also called staff attrition, it is major problem in these days.It is the loss of employees in a company due to certain factors such as retirement, resignation, or termination of employment. Staff attrition is the cycle in which employees in a company vacate their official role permanently.
# * If a company doesnt have a satisfied employees,it will not have satisfied customers,shareholders as well.
# * The projects on progress are mainly affected towards the deaadline.It delays the project completion and the relationship with the clientss as well.
# * In order to deal with attrition problem we have to predict the attrition beforehead and this will help us to replace the another employee in the same position in time, so that the workflow doesnot get affected.
# * It is very important to understand the causes of employee dissatisfaction in order to reduce attrition rate in a company.

# %%
from IPython.display import Image  #importing libary to display the image
import os  #import operating system to direct the folders
Image("/kaggle/input/causes-of-employeeattrition/causes-of-high-employee-attrition.png")

# %% [markdown]
# # HR Analytics
#
# * HR analytics allows HR professionals to make informed decisions and create strategies that will benefit employees and support organizational goals. This has a significant impact on organizational performance, leading to as much as a 25% rise in business productivity, a 50% decrease in attrition rates, and an 80% increase in recruiting efficiency.
# * HR analytics is concerned with many areas of the organization at large.This could include day-to-day HR operations,procedure effeciencies,or startegic organizational issues in other areas.

# %%
from IPython.display import Image  #importing libary to display the image
import os  #import operating system to direct the folders
Image("/kaggle/input/benfitis-of-hr-analytics/benefits-of-HR-analytics-2.jpg")

# %% [markdown]
# # problem:
# XYZ company which was established a few years back is facing around a 15% attrition rate for
# a couple of years. And it's majorly affecting the company in many aspects.
# * what are the factors for employee attrition?
# * how to reduce employee attrition?

# %% [markdown]
# # Goal of project:
# *  In this project ,we need to do HR analytics to explore the underlying factors of employee via  exploatory data anlysis  to predict when an employee would attrite. the analysis reveal key patterns in employee attrition.
# * to find the precautions should taken by the organization to reduce attrition rate in next year.

# %% [markdown]
# # loading dataset by using pandas

# %%
data=pd.read_csv("/kaggle/input/employee-atrrition-data/Attrition data.csv")
data
# Out:
#       EmployeeID  Age Attrition     BusinessTravel              Department  \
# 0              1   51        No      Travel_Rarely                   Sales
# 1              2   31       Yes  Travel_Frequently  Research & Development
# 2              3   32        No  Travel_Frequently  Research & Development
# 3              4   38        No         Non-Travel  Research & Development
# 4              5   32        No      Travel_Rarely  Research & Development
# ...          ...  ...       ...                ...                     ...
# 4405        4406   42        No      Travel_Rarely  Research & Development
# 4406        4407   29        No      Travel_Rarely  Research & Development
# 4407        4408   25        No      Travel_Rarely  Research & Development
# 4408        4409   42        No      Travel_Rarely                   Sales
# 4409        4410   40        No      Travel_Rarely  Research & Development
#
# ...

# %% [markdown]
# # About Dataset
#  This dataset have 1 csv file with 4410 rows  and 29 columns:
#  * EmployeeID : unique employee id
#  * Age: age of the employee
#  * Attrition: the employee want to undergo attrition (yes or NO)
#  * BusinessTravel : how frequently employee going for business trips
#  * Department : department of the employee
#  * DistanceFromHome: diatnce in kms
#  * Education :background education of employee
#  * EducationField : stream
#  * EmployeeCount:count of employess working under him?
#  * JobLevel: level of job
#  * maritual status: relationship status
#  * MonthlyIncome:annual income
#  * overall18:metrics of employee
#  * NumCompaniesWorked:no.of companines employee worked before
#  * PercentSalaryHike:how much hike can a employee eligible for?
#  * StandardHours: working hours
#  * Gender:sex of employee
#  * TotalWorkingYears:experience
#  * TrainingTimesLastYear: how many trainings employee went for?
#  * YearsAtCompany: how many years employee working in the xyz company?
#  * YearsSinceLastPromotion : how many years have been since employee got last promotion?
#  * YearsWithCurrManager: how many years with current manager?
#  * EnvironmentSatisfaction:employee opionion about work environment
#  * JobSatisfaction: employee opinon about job statsifation
#  * WorkLifeBalance:how  is employee work life balance?
#  * JobInvolvement:is employee invovled in jobs
#  * PerformanceRating:how is performace of a employee?

# %% [markdown]
# # Data Prepartion
# * explorings rows and columns

# %%
df=pd.DataFrame(data)
df
# Out:
#       EmployeeID  Age Attrition     BusinessTravel              Department  \
# 0              1   51        No      Travel_Rarely                   Sales
# 1              2   31       Yes  Travel_Frequently  Research & Development
# 2              3   32        No  Travel_Frequently  Research & Development
# 3              4   38        No         Non-Travel  Research & Development
# 4              5   32        No      Travel_Rarely  Research & Development
# ...          ...  ...       ...                ...                     ...
# 4405        4406   42        No      Travel_Rarely  Research & Development
# 4406        4407   29        No      Travel_Rarely  Research & Development
# 4407        4408   25        No      Travel_Rarely  Research & Development
# 4408        4409   42        No      Travel_Rarely                   Sales
# 4409        4410   40        No      Travel_Rarely  Research & Development
#
# ...

# %%
df.head() #first5 columns of dataset
# Out:
#    EmployeeID  Age Attrition     BusinessTravel              Department  \
# 0           1   51        No      Travel_Rarely                   Sales
# 1           2   31       Yes  Travel_Frequently  Research & Development
# 2           3   32        No  Travel_Frequently  Research & Development
# 3           4   38        No         Non-Travel  Research & Development
# 4           5   32        No      Travel_Rarely  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  Gender  ...  \
# 0                 6          2  Life Sciences              1  Female  ...
# 1                10          1  Life Sciences              1  Female  ...
# 2                17          4          Other              1    Male  ...
# 3                 2          5  Life Sciences              1    Male  ...
# 4                10          1        Medical              1    Male  ...
#
#    TotalWorkingYears TrainingTimesLastYear YearsAtCompany  \
# ...

# %%
df.tail(5) #bottom 5  columns of dataset
# Out:
#       EmployeeID  Age Attrition BusinessTravel              Department  \
# 4405        4406   42        No  Travel_Rarely  Research & Development
# 4406        4407   29        No  Travel_Rarely  Research & Development
# 4407        4408   25        No  Travel_Rarely  Research & Development
# 4408        4409   42        No  Travel_Rarely                   Sales
# 4409        4410   40        No  Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  Gender  ...  \
# 4405                 5          4        Medical              1  Female  ...
# 4406                 2          4        Medical              1    Male  ...
# 4407                25          2  Life Sciences              1    Male  ...
# 4408                18          2        Medical              1    Male  ...
# 4409                28          3        Medical              1    Male  ...
#
#       TotalWorkingYears TrainingTimesLastYear YearsAtCompany  \
# ...

# %%
df.describe()  #gives the summary about the dataset in detailed form
# Out:
#         EmployeeID          Age  DistanceFromHome    Education  EmployeeCount  \
# count  4410.000000  4410.000000       4410.000000  4410.000000         4410.0
# mean   2205.500000    36.923810          9.192517     2.912925            1.0
# std    1273.201673     9.133301          8.105026     1.023933            0.0
# min       1.000000    18.000000          1.000000     1.000000            1.0
# 25%    1103.250000    30.000000          2.000000     2.000000            1.0
# 50%    2205.500000    36.000000          7.000000     3.000000            1.0
# 75%    3307.750000    43.000000         14.000000     4.000000            1.0
# max    4410.000000    60.000000         29.000000     5.000000            1.0
#
#           JobLevel  MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  \
# count  4410.000000    4410.000000         4391.000000        4410.000000
# mean      2.063946   65029.312925            2.694830          15.209524
# ...

# %%
df.info()#gives the information like datatypes and null count for every columns and rows in dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4410 entries, 0 to 4409
# Data columns (total 29 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   EmployeeID               4410 non-null   int64
#  1   Age                      4410 non-null   int64
#  2   Attrition                4410 non-null   object
#  3   BusinessTravel           4410 non-null   object
#  4   Department               4410 non-null   object
#  5   DistanceFromHome         4410 non-null   int64
#  6   Education                4410 non-null   int64
#  7   EducationField           4410 non-null   object
#  8   EmployeeCount            4410 non-null   int64
#  9   Gender                   4410 non-null   object
#  10  JobLevel                 4410 non-null   int64
#  11  JobRole                  4410 non-null   object
#  12  MaritalStatus            4410 non-null   object
#  13  MonthlyIncome            4410 non-null   int64
# ...

# %%
type(df) #dataset type is  dataframe as it is the combination of  mutlple series
# Out:
# pandas.core.frame.DataFrame

# %%
type(df["JobLevel"])  #single column in dataset will be consider as series
# Out:
# pandas.core.series.Series

# %%
df.shape
# Out:
# (4410, 29)
